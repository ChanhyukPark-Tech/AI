# %%
import random
from math import exp,log
X = [(0,0),(1,0),(0,1),(1,1)]
Y = [0,0,0,1]

# %%
class logistic_regression_model():
    def __init__(self):
        self.w = [random.random(), random.random()]
        self.b = random.random()
        
    def sigmoid(self,z):
        return 1/(1 + exp(-z))
    def predict(self,x):
        z = self.w[0] * x[0] + self.w[1] * x[1] + self.b
        a = self.sigmoid(z)
        return a

# %%
model = logistic_regression_model()

# %%
def train(X,Y,model,lr = 0.1):
    dw0 = 0.0
    dw1 = 0.0
    db = 0.0
    m = len(X)
    cost = 0.0
    
    for x,y in zip(X,Y):
        a = model.predict(x)
        if y == 1:
            cost -= log(a)
        else:
            cost -= log(1-a)
        
        
        dw0 += (a-y)*x[0]
        dw1 += (a-y)*x[1]
        db += (a-y)
        
    model.w[0] -= lr * dw0/m
    model.w[1] -= lr * dw1/m
    model.b -= lr * db/m
        
    return cost

# %%
for epoch in range(10000):
    cost = train(X,Y,model,0.1)
    if epoch % 100 == 0:
        print(epoch,cost)
# Out:
# 0 0.5669670325448277
# 100 0.5280543552448254
# 200 0.49403402814265135
# 300 0.46403137388634075
# 400 0.4373722879585813
# 500 0.4135276618545688
# 600 0.392075668042563
# 700 0.37267544742140635
# 800 0.3550483084348748
# 900 0.33896401197592335
# 1000 0.3242305831246766
# 1100 0.3106866207582573
# 1200 0.29819540961261626
# 1300 0.28664035478495425
# 1400 0.27592140104229484
# 1500 0.26595219538976744
# 1600 0.256657817431963
# 1700 0.24797294828489552
# 1800 0.23984038163555332
# 1900 0.2322098042083809
# 2000 0.2250367901696994
# 2100 0.2182819667586121
# 2200 0.21191031795971504
# 2300 0.2058906002193997
# 2400 0.20019484967958012
# 2500 0.19479796460571086
# 2600 0.18967734994058127
# 2700 0.18481261345477595
# 2800 0.18018530496011365
# 2900 0.17577869163091195
# 3000 0.17157756373446126
# 3100 0.16756806607828117
# 3200 0.1637375512919796
# 3300 0.16007445171740364
# 3400 0.15656816721443706
# 3500 0.15320896662600197
# 3600 0.14998790100408002
# 3700 0.14689672699399892
# 3800 0.14392783901892542
# 3900 0.14107420910993798
# 4000 0.13832933339681894
# 4100 0.13568718441692526
# 4200 0.13314216851900496
# 4300 0.13068908773961324
# 4400 0.12832310561505134
# 4500 0.12603971646409318
# 4600 0.12383471773835086
# 4700 0.12170418508967502
# 4800 0.11964444984896483
# 4900 0.11765207864937008
# 5000 0.11572385496005165
# 5100 0.1138567623253185
# 5200 0.11204796912870651
# 5300 0.11029481472301135
# 5400 0.1085947967859217
# 5500 0.1069455597770986
# 5600 0.10534488438669307
# 5700 0.10379067787764418
# 5800 0.10228096523491595
# 5900 0.10081388104432526
# 6000 0.0993876620319462
# 6100 0.0980006402024313
# 6200 0.09665123652105823
# 6300 0.09533795509003545
# 6400 0.0940593777746744
# 6500 0.09281415923950895
# 6600 0.09160102235845119
# 6700 0.0904187539665957
# 6800 0.08926620092445672
# 6900 0.0881422664682323
# 7000 0.08704590682220126
# 7100 0.08597612805161514
# 7200 0.08493198313645017
# 7300 0.08391256924820059
# 7400 0.08291702521351005
# 7500 0.08194452914989774
# 7600 0.08099429626014398
# 7700 0.08006557677308815
# 7800 0.0791576540196558
# 7900 0.07826984263389065
# 8000 0.07740148686965118
# 8100 0.07655195902440173
# 8200 0.07572065796226429
# 8300 0.07490700772912383
# 8400 0.07411045625318795
# 8500 0.07333047412492447
# 8600 0.07256655345079113
# 8700 0.07181820677562095
# 8800 0.07108496606891898
# 8900 0.07036638177070925
# 9000 0.069662021892896
# 9100 0.0689714711724213
# 9200 0.06829433027277318
# 9300 0.06763021503066781
# 9400 0.06697875574495334
# 9500 0.0663395965050122
# 9600 0.06571239455613025
# 9700 0.06509681969948546
# 9800 0.06449255372457824
# 9900 0.06389928987208429

# %%
model.predict([1,1])
# Out:
# 0.9742073020068336

# %%
model.predict([0,1])
# Out:
# 0.018416432845337817

# %%
model.predict([0,0])
# Out:
# 9.319610210470434e-06
